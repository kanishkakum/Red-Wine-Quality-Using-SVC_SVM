# %% [markdown]
# # RED WINE QUALITY ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# **Data Ingestion**

# %%
data=pd.read_csv("https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# **Basic Information about the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# There are total 1599 rows and 12 features in the dataset

# %%
#checking the features of the dataset
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# **Describing the dataset**

# %%
data.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
#checking null values
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# From above we can say that there is no null data in the dataset

# %% [markdown]
# **Checking total classes in the dataset of Quality**

# %%
data.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# This is basically a multi class classification problem

# %% [markdown]
# # EDA

# %% [markdown]
# **Dependent Variable** - quality feature of the dataset is basically the dependent variable

# %%
#plotting the count plot for the dependent variable
plt.figure(figsize=(8,6))
sns.countplot(x='quality',data=data,saturation=0.90)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# *univariate Analysis of Independent Variable*

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
Ind_fea=data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density','pH', 'sulphates', 'alcohol']]

# %%
plt.figure(figsize=(14,15))
plt.suptitle("Analysis of Independent Variable",horizontalalignment='center',fontsize=15)
for i in range(0, len(Ind_fea.columns)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=Ind_fea[Ind_fea.columns[i]], shade='fill', data = data)
    plt.tight_layout()

# %%
#checking the outlier in the distribution
plt.figure(figsize=(14,15))
plt.suptitle("Boxplot for Independent Variable",horizontalalignment='center',fontsize=15)
for i in range(0, len(Ind_fea.columns)):
    plt.subplot(5,3,i+1)
    sns.boxplot(x=Ind_fea[Ind_fea.columns[i]],  data = data)
    plt.tight_layout()

# %% [markdown]
# We can see there is outlier in our dataset which can affect our prediction. In order to make our model efficient we have to remove outlier or we can perform perform transform on the independent variable.

# %%
Ind_fea.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
Ind_fea.shape
# Out:
# (1599, 11)

# %%
def remove_outlier_IQR(Ind_fea):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    df_final=Ind_fea[~((Ind_fea<(Q1-1.5*IQR)) | (Ind_fea>(Q3+1.5*IQR)))]
    return df_final

# %%
df_final.shape
# Out:
# (1599, 11)

# %%
#checking the outlier in the distribution
plt.figure(figsize=(14,15))
plt.suptitle("Boxplot for Independent Variable",horizontalalignment='center',fontsize=15)
for i in range(0, len(df_final.columns)):
    plt.subplot(5,3,i+1)
    sns.boxplot(x=df_final[df_final.columns[i]],  data = df_final)
    plt.tight_layout()

# %%
#checking the distribution 
plt.figure(figsize=(14,15))
plt.suptitle("Analysis of Independent Variable",horizontalalignment='center',fontsize=15)
for i in range(0, len(df_final.columns)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df_final[df_final.columns[i]], shade='fill', data = df_final)
    plt.tight_layout()

# %%
data.shape
# Out:
# (1599, 12)

# %%
df_final.shape
# Out:
# (1599, 11)

# %% [markdown]
# # Checking the correlation between Independent variable

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_final.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Independent Variable
X=df_final

# %%
#dependent Variable
Y=data['quality']

# %% [markdown]
# # Relationship between dependent and independent variable

# %%
plt.figure(figsize=(14,15))
plt.suptitle('Relationship between Dependent and Independent Variable', fontsize=12, fontweight='bold')
plotnumber=1
for i in X:
    if plotnumber<=9:
        plt.subplot(3,4,plotnumber)
        sns.stripplot(Y,X[i])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Model Training and testing

# %%
# separate dataset into train and test
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-cc32830a595b> in <module>
#       1 # separate dataset into train and test
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)
#       3 print(X_train.shape, X_test.shape)
#       4 print(Y_train.shape, Y_test.shape)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
X_scaled =scalar.fit_transform(X)
